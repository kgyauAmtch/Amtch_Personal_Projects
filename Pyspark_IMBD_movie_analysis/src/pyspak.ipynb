# %%
# Set the PySpark environment variables
import os
os.environ['SPARK_HOME'] = "/Users/gyauk/codetools/Spark"
os.environ["JAVA_HOME"] = "/Library/Java/JavaVirtualMachines/temurin-11.jdk/Contents/Home"
os.environ['PYSPARK_DRIVER_PYTHON'] = 'jupyter'
os.environ['PYSPARK_DRIVER_PYTHON_OPTS'] = 'lab'
os.environ['PYSPARK_PYTHON'] = 'python'

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import desc

# %%
import pyspark
print('hello')
# Out:
# hello

# %%
from pyspark.sql import SparkSession

# Create a SparkSession
spark = SparkSession.builder.appName('MovieAnalysis').getOrCreate()
# Out:
# 25/04/19 09:25:57 WARN Utils: Your hostname, Gyaus-MacBook-Pro.local resolves to a loopback address: 127.0.0.1; using 192.168.100.6 instead (on interface en0)
# 25/04/19 09:25:57 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/04/19 09:25:58 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
spark.version
# Out:
# '3.5.5'
